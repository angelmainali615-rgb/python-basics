# %%
#### Session Objectives:
*   Understand the motivation behind Object-Oriented Programming.
*   Learn the core concepts: Classes, Objects, Attributes, and Methods.
*   Learn how to define a simple class in Python.
*   Understand the purpose and usage of the `__init__` constructor method.
*   Learn how to create instances (objects) of a class.
*   Learn how to access object attributes and call object methods.

# %%
OOPs:
Analogy: Building a house
    A class is like a blueprint — it defines the structure and features (walls, doors, rooms).
    An object is a real house built from that blueprint — each with its own color, size, and number of rooms.

OOP helps by:
    Organizing code around real-world concepts
    Making it easier to reuse, extend, and maintain
    Allowing creation of multiple unique instances from a single design

# %%
### Core OOP Concepts

1. Class
    A blueprint for creating objects.
    Like a house plan that defines what every house should have.
    class House:


2. Object (Instance)
    A concrete version of a class with real values.
    A specific house built from the blueprint.
    my_house = House()


3. Attribute
    Data stored in an object.
    Features of a house like color, size, address.
    my_house.color = "blue"


4. Method
    A function inside a class that defines behavior.
    Actions like open_door(), turn_on_lights().
    my_house.open_door()

# %%
class Dog:
    pass

# %%
#creating class objects 
dog1=Dog()
dog2=Dog()

# %%
print(type(dog1))
print(type(dog2))

print(dog1)
print(dog2)
print(dog1 == dog2)
# Out:
# <class '__main__.Dog'>
# <class '__main__.Dog'>
# <__main__.Dog object at 0x0000028F227F7A10>
# <__main__.Dog object at 0x0000028F22665E50>
# False

# %%
### the __init__ constructor

# %%
class Dog:
    def __init__(self,name,breed,age):
        self.name=name
        self.breed=breed
        self.age=age
        print(f"A new Dog object named {self.name} was created!")

# %%
#Creating objects with attributes
dog1 = Dog("Buddy", "Golden Retriever", 3)
dog2 = Dog("Lucy", "German Shepherd", 5)
# Out:
# A new Dog object named Buddy was created!
# A new Dog object named Lucy was created!

# %%
dog1.name
# Out:
# 'Buddy'

# %%
dog2.age
# Out:
# 5

# %%
# Accessing Attributes
# We use the dot (`.`)

# `object_name.attribute_name`


print(f"Dog 1's Name: {dog1.name}")
print(f"Dog 1's Breed: {dog1.breed}")
print(f"Dog 1's Age: {dog1.age}")


print(f"\nDog 2's Name: {dog2.name}")
print(f"Dog 2's Breed: {dog2.breed}")
print(f"Dog 2's Age: {dog2.age}")

print(f"\nIs dog1's name the same as dog2's name? {dog1.name == dog2.name}")
# Out:
# Dog 1's Name: Buddy
# Dog 1's Breed: Golden Retriever
# Dog 1's Age: 3
#
# Dog 2's Name: Lucy
# Dog 2's Breed: German Shepherd
# Dog 2's Age: 5
#
# Is dog1's name the same as dog2's name? False

# %%
### Defining Methods

# Methods are functions defined inside a class that define the object's behavior. They also take `self` as the first parameter,
# allowing them to access and modify the object's attributes.


class Dog:
    def __init__(self, name, breed, age):
        self.name = name
        self.breed = breed
        self.age = age
        print(f"A new Dog object named {self.name} was created!")


    def bark(self):
        print(f"{self.name} says: Woof! Woof!")

    def describe(self):
        print(f"This is {self.name}, a {self.age}-year-old {self.breed}.")

    def have_birthday(self):
        self.age += 1
        print(f"Happy Birthday, {self.name}! You are now {self.age} years old.")

# %%
dog3=Dog("Samir","bulldog",4)
dog4=Dog("kriti","huskey",5)
# Out:
# A new Dog object named Samir was created!
# A new Dog object named kriti was created!

# %%
dog3.bark()
# Out:
# Samir says: Woof! Woof!

# %%
dog3.describe()
# Out:
# This is Samir, a 4-year-old bulldog.

# %%
dog3.have_birthday()
# Out:
# Happy Birthday, Samir! You are now 5 years old.

# %%
class Dog:
    def __init__(self, name, breed, age):
        self.name = name
        self.breed = breed
        self.age = age
        print(f"A new Dog object named {self.name} was created!")


    def bark(self):
        print(f"{self.name} says: Woof! Woof!")

    def describe(self,location):
        print(f"This is {self.name}, a {self.age}-year-old {self.breed}.Normally found in {location}")

    def have_birthday(self):
        self.age += 1
        print(f"Happy Birthday, {self.name}! You are now {self.age} years old.")

# %%
dog4=Dog("Shristita","bulldog",4)
# Out:
# A new Dog object named Shristita was created!

# %%
dog4.describe("Bhaktapur")
# Out:
# This is Shristita, a 4-year-old bulldog.Normally found in Bhaktapur

# %%
class student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        print(f"A new student object named {self.name} was created!")
    def introduce(self, College):
        print(f"Hi! my name is {self.name} and Iam {self.age} years old. I study in {College}")

# %%
student1=student("Angel",20)
student2=student("Samir",19)
# Out:
# A new student object named Angel was created!
# A new student object named Samir was created!

# %%
student1.introduce("Patan Multiple Campus")
student2.introduce("Blue Bird College")
# Out:
# Hi! my name is Angel and Iam 20 years old. I study in Patan Multiple Campus
# Hi! my name is Samir and Iam 19 years old. I study in Blue Bird College

# %% [markdown]
# # __Inheritance__

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        print(f"Person object created: {self.name}")

    def introduce(self):
        print(f"Hi, my name is {self.name} and I am {self.age} years old.")

    def walk(self):
        print(f"{self.name} is walking.")

# %%
#create a person object
p1=Person("Angel",20)
p1.introduce()
p1.walk()
# Out:
# Person object created: Angel
# Hi, my name is Angel and I am 20 years old.
# Angel is walking.

# %%
#syntax: class ClassName(ParentClassName)

class Student(Person):
    pass
s1=Student("Bob",19)
print(f"Student's Name:{s1.name}")
s1.introduce()
s1.walk()
# Out:
# Person object created: Bob
# Student's Name:Bob
# Hi, my name is Bob and I am 19 years old.
# Bob is walking.

# %%
class Student(Person):
    def __init__(self,name,age,student_id,course):
        super().__init__(name,age)
        self.student_id=student_id
        self.course=course
    def intro(self):
        print(f"Hello! Iam {self.name}, my student id {self.student_id} and my course is {self.course}")
    def introduce(self):
        super().introduce()
        print(f"Good Morning!  my student id {self.student_id} and my course is {self.course}")
student1=Student("Angel",19,"ID40","Bsc CSIT")
# Out:
# Person object created: Angel

# %%
student1.intro()
# Out:
# Hello! Iam Angel, my student id ID40 and my course is Bsc CSIT

# %%
student1.introduce()
# Out:
# Hi, my name is Angel and I am 19 years old.
# Good Morning!  my student id ID40 and my course is Bsc CSIT

# %%
s1.introduce()
# Out:
# Hi, my name is Bob and I am 19 years old.

# %%
student1.name="Samir"

# %%
student1.name
# Out:
# 'Samir'

# %% [markdown]
# # ## Part 3: Encapsulation
#
# # It involves **restricting direct access** to some of an object's components (data hiding).
#
# # **Why use Encapsulation?**
# # *   **Data Protection:** Prevent accidental or unwanted modification of an object's internal state from outside the class.
# # *   **Control:** The class controls how its data is accessed and modified (e.g., through specific methods like `deposit()` or `withdraw()` instead of directly changing a `balance` attribute).
# # *   **Simplicity:** Hides complex internal details from the user of the class, providing a simpler interface.
# # *   **Flexibility:** The internal implementation can change without affecting the code that uses the class, as long as the public interface (methods) remains the same.

# %%
class BankAccount:
    def __init__(self, owner, initial_balance=0):
        self.owner = owner
        self._balance = initial_balance
        self.__pin = "5678"
        print(f"Account created for {self.owner}")

    def intro(self):
        print(f"Owner Name:{self.owner}")
       
    # Public method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self._balance += amount
            print(f"Deposited ${amount}. New balance: ${self._balance}")
        else:
            print("Deposit amount must be positive.")

    # Public method to withdraw money
    def withdraw(self, amount):
        if amount <= 0:
            print("Withdrawal amount must be positive.")
        elif amount > self._balance:
            print(f"Insufficient funds. Cannot withdraw ${amount}. Balance is ${self._balance}")
        else:
            self._balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self._balance}")

    # Public method to get balance (controlled access)
    def get_balance(self):
        print(f"Current balance for {self.owner}: ${self._balance}")
        # We can access the "private" attribute internally
        # print(f"   (Pin : {self.__pin})")
        return self._balance

    def get_pin(self):
        if self._BankAccount__pin == self.__pin:
            print(id(self._BankAccount__pin))
            print(id(self.__pin))
           
            print(f"   (Current pin  is: {self._BankAccount__pin})")
        return self.__pin
    def new_pin(self,pin):
        if self._BankAccount__pin==self.__pin:
            self._BankAccount__pin=pin 
        return  print(f"Changed pin is:{self._BankAccount__pin}")

# %%
owner1=BankAccount("Angel", 20000)
# Out:
# Account created for Angel

# %%
owner1.owner
# Out:
# 'Angel'

# %%
owner1._balance
# Out:
# 20000

# %%
owner1.new_pin(3456)
# Out:
# Changed pin is:3456

# %%
owner1.intro()
# Out:
# Owner Name:Angel

# %%
owner1.deposit(40000)
# Out:
# Deposited $40000. New balance: $60000

# %%
owner1.withdraw(30000)
# Out:
# Withdrew $30000. New balance: $30000

# %%
owner1.get_balance()
# Out:
# Current balance for Angel: $30000
# 30000

# %%
owner1.get_pin()
# Out:
# 2847189932656
# 2847189932656
#    (Current pin  is: 5678)
# '5678'

# %%
owner1._BankAccount__pin="3540"

# %%
owner1._BankAccount__pin
# Out:
# 3456

# %%
owner1.get_pin()
# Out:
# 2847194457680
# 2847194457680
#    (Current pin  is: 3456)
# 3456

# %% [markdown]
# ### Abstraction

# %% [markdown]
# #### Abstraction means:
# * Hiding complicated stuff (like wires inside the controller).
# * Showing only what’s important (the buttons you need to press).

# %%
# ABC (Abstract Base Class)
from abc import ABC, abstractmethod

# Create an abstract class
class Animal(ABC):
   
    @abstractmethod
    def make_sound(self):
        pass
   
    @abstractmethod
    def move(self):
        pass
   
    def sleep(self):
        print("Zzz... sleeping")
        return

# Create concrete classes that inherit from Animal
class Dog(Animal):
   
    def make_sound(self):
        print("Woof! Woof!")
   
    def move(self):
        print("Running on four legs")

    def number_of_legs(self):
        print("Have four legs")

class Bird(Animal):
   
    def make_sound(self):
        print("Chirp! Chirp!")
   
    def move(self):
        print("Flying in the sky")

    def number_of_legs(self):
        print("Have 2 legs")

# %%
animal1=Animal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 animal1=Animal()
#
# TypeError: Can't instantiate abstract class Animal without an implementation for abstract methods 'make_sound', 'move'

# %%
dog1=Dog()

# %%
dog1.make_sound()
# Out:
# Woof! Woof!

# %%
dog1.move()
dog1.number_of_legs()
dog1.sleep()
# Out:
# Running on four legs
# Have four legs
# Zzz... sleeping

# %%
bird1=Bird()

# %%
bird1.make_sound()
# Out:
# Chirp! Chirp!

# %%
bird1.move()
bird1.number_of_legs()
bird1.sleep()
# Out:
# Flying in the sky
# Have 2 legs
# Zzz... sleeping

# %%
# Create instances of concrete classes
dog = Dog()
bird = Bird()

# Demonstrate abstraction in action
print("\nDog behaviors:")
dog.make_sound()
dog.move()
dog.number_of_legs()
dog.sleep()

print("\nBird behaviors:")
bird.make_sound()
bird.move()
bird.number_of_legs()
bird.sleep()
# Out:
# Dog behaviors:
# Woof! Woof!
# Running on four legs
# Have four legs
# Zzz... sleeping
#
# Bird behaviors:
# Chirp! Chirp!
# Flying in the sky
# Have 2 legs
# Zzz... sleeping

# %%
class Book:
    def __init__(self,title,author,price):
        self.title=title
        self.author=author
        self.price=price
        print(f"Book object created:{self.title}")
    def display_info(self):
        print(f"The title of the book is:{self.title}")
        print(f"The Author of the book {self.title} is:{self.author}")
        print(f"The price of book is:{self.price}")
Book1=Book("Muna Madan","Laxmi Prasad Devkota",1000)
Book2=Book("Clean Code","Robert C.Martin",1500)
Book1.display_info()
Book2.display_info()
# Out:
# Book object created:Muna Madan
# Book object created:Clean Code
# The title of the book is:Muna Madan
# The Author of the book Muna Madan is:Laxmi Prasad Devkota
# The price of book is:1000
# The title of the book is:Clean Code
# The Author of the book Clean Code is:Robert C.Martin
# The price of book is:1500

# %%
class Circle:
    def __init__(self,radius):
        self.radius=radius
    def area_of_circle(self):
        Area=3.14*(self.radius)**2
        print(f"Area of Circle is:{Area}")
    def circumference_of_circle(self):
        Circumference=2*3.14*(self.radius)
        print(f"Circumference of Circle is:{Circumference}")
circle1=Circle(3)
circle1.area_of_circle()
circle1.circumference_of_circle()
# Out:
# Area of Circle is:28.26
# Circumference of Circle is:18.84

# %%
class Student:
    def __init__(self,name,roll_number,marks):
        self.name=name
        self.roll_number=roll_number
        self.marks=marks #list of 5 subject marks
    def calc_average(self):
        total=0
        count=0
        for m in self.marks:
            total+=m
            count+=1
        return total/count
    def calc_grade(self):
        average=self.calc_average()
        if average>=90:
            return "A"
        elif average>=75:
            return "B"
        elif average>=50:
            return "c"
        else:
            return "F"
    def display(self):
        print("Name:", self.name)
        print("Roll Number:", self.roll_number)
        print("Average Marks:", self.calc_average())
        print("Grade:", self.calc_grade())
marks = [85, 78, 92, 88, 80]
student1 = Student("Angel Mainali", 12, marks)
student1.display()
# Out:
# Name: Angel Mainali
# Roll Number: 12
# Average Marks: 84.6
# Grade: B

# %%
class Vehicle:
    def __init__(self,make,model):
        self.make=make
        self.model=model
    def display_info(self):
        print(f" Make :{self.make}")
        print(f"The model is:{self.model}")

class Car(Vehicle):
    def __init__(self,make,model,num_doors):
        super().__init__(make,model)
        self.num_doors=num_doors
    def display_info(self):
        super().display_info()
        print(f"The number of doors in Vehicle is:{self.num_doors}")
car1=Car("Toyota","360",4)
car1.display_info()
# Out:
#  Make :Toyota
# The model is:360
# The number of doors in Vehicle is:4

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
class Manager(Employee):
    def __init__(self,name,salary, Department):
        super().__init__(name,salary)
        self.Department=Department
    def display_info(self):
        print(f"Manager's Name:{self.name}")
        print(f"Salary  :{self.salary}")
        print(f"Department:{self.Department}")
Manager1=Manager("Angel Mainali",40000,"IT")
Manager1.display_info()
# Out:
# Manager's Name:Angel Mainali
# Salary  :40000
# Department:IT

# %%
class Shape:
    def __init__(self):
         def area(self):
             print("Area not defined")
class Rectangle(Shape):
    def __init__(self,length,breadth):
        self.length=length
        self.breadth=breadth
    def area(self):
        Area=(self.length)*(self.breadth)
        print(f"The area of Rectangle is:{Area}")
class Triangle(Shape):
    def __init__(self,breadth,height):
        self.breadth=breadth
        self.height=height
    def area(self):
        Area=0.5*(self.breadth)*(self.height)
        print(f"The area of Triangle is:{Area}")

rectangle1=Rectangle(5,6)
rectangle1.area()
triangle1=Triangle(5,6)
triangle1.area()
# Out:
# The area of Rectangle is:30
# The area of Triangle is:15.0

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
     @abstractmethod
     def start_engine(self):
        pass
     @abstractmethod
     def stop_engine(self):
        pass 
class Car(Vehicle):
    def start_engine(self):
        print("Car Engine starts with a Key.")
    def stop_engine(self):
        print("Car Engine stopped.")
class Motorcycle(Vehicle):
    def start_engine(self):
        print("Motorcycle Engine start with a self-start button.")
    def stop_engine(self):
        print("Motorcycle Engine stopped.")

car=Car()
bike=Motorcycle()
car.start_engine()
car.stop_engine()
bike.start_engine()
bike.stop_engine()
# Out:
# Car Engine starts with a Key.
# Car Engine stopped.
# Motorcycle Engine start with a self-start button.
# Motorcycle Engine stopped.

# %%
from abc import ABC, abstractmethod

class Payment(ABC):
    @abstractmethod
    def pay(self,amount):
        pass
class CreditCardPayment(Payment):
    def pay(self,amount):
        print(f"Paid {amount} units using creditcard.")
class PayPalPayment(Payment):
    def pay(self,amount):
        print(f"Paid {amount} units using PayPal.")

credit_payment = CreditCardPayment()
paypal_payment = PayPalPayment()

credit_payment.pay(100)
paypal_payment.pay(100)
# Out:
# Paid 100 units using creditcard.
# Paid 100 units using PayPal.

# %%
class Employee:
    def __init__(self,name,salary):
        self.__name=name
        self.__salary=salary
   #Getter for name
    def get_name(self):
        return self.__name
   #Getter for salary
    def get_salary(self):
        return self.__salary
     #setter for salary
    def set_salary(self,amount):
        if amount>0:
            self.__salary=amount
        else:
            print("Amount must be positive")

emp1=Employee("Angel",20000)
print(f"Name:{emp1.get_name()}")
print(f"Salary:{emp1.get_salary()}")
emp1.set_salary(40000)
print(f"Updated salary:{emp1.get_salary()}")
# Out:
# Name:Angel
# Salary:20000
# Updated salary:40000

# %%
class Student:
    def __init__(self, name):
        self.__name = name          # private attribute
        self.__marks = []           # private list of marks
    def set_marks(self, mark):
        if 0 <= mark <= 100:
            self.__marks.append(mark)
        else:
            print("Invalid mark! Marks must be between 0 and 100.")
    def get_average(self):
        total = 0
        count=0
        for m in self.__marks:
            total += m
            count+=1
        return total /count
    def display(self):
        print("Name:", self.__name)
        print("Marks:", self.__marks)
        print("Average:", self.get_average())
student = Student("Angel")
student.set_marks(85)
student.set_marks(90)
student.set_marks(78)
student.set_marks(110)   # Invalid mark
student.display()
# Out:
# Invalid mark! Marks must be between 0 and 100.
# Name: Angel
# Marks: [85, 90, 78]
# Average: 84.33333333333333

# %% [markdown]
# ## POLYMORPHISM

# %% [markdown]
# # Polymorphism in Python
#
# Polymorphism allows objects of different classes to be treated as objects of a common superclass. It enables functions to use entities of different types at different times.
#
# ## Key Points:
# - Same interface, different behavior
# - Useful in method overriding and operator overloading
# - Promotes code reusability and flexibility

# %%
class Dog:
    def speak(self):
        print("Woof!")

class Cat:
    def speak(self):
        print("Meow!")

class Duck:
    def speak(self):
        print("Quack!")

   

dog = Dog()
cat = Cat()
duck = Duck()
print(cat)
# Out:
# <__main__.Cat object at 0x0000027AD2034AD0>

# %%
def make_it_speak(animal):
    animal.speak()

animal=[dog,cat,duck]
for item in animal:
    make_it_speak(item)
# Out:
# Woof!
# Meow!
# Quack!

# %%
make_it_speak(cat)
# Out:
# Meow!

# %%
class Dog:
    def __str__(self):
        return f"Dog str"
    def speak(self):
        print("Woof!")

class Cat:
    def __str__(self):
        return f"Cat str"
    def speak(self):
        print("Meow!")

class Duck:
    def speak(self):
        print("Quack!")

   

dog = Dog()
cat = Cat()
duck = Duck()
print(dog)
# Out:
# Dog str

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def __str__(self):
        return f"Title: {self.title}, Book Author :{self.author}"
       
# Create a book instance
book1 = Book("Python Crash Course", "Eric Matthes", 193)

# Print the book object
print("--- Printing book object (default) ---")
print(book1)
print(str(book1))
# Out:
# --- Printing book object (default) ---
# Title: Python Crash Course, Book Author :Eric Matthes
# Title: Python Crash Course, Book Author :Eric Matthes

# %%
class House:
    def __init__(self, owner, member, vehicle):
        self.owner = owner
        self.member = member
        self.vehicle = vehicle

    def __str__(self):
        # This defines what print(house_object) will show
        return f"Owned by '{self.owner}' with {self.member} members and have ({self.vehicle}) vehicles."

# Create a house instance
house1 = House("Elon Mask", 4, 193)

# Print the house object
print("--- Printing house object (default) ---")
print(house1)
str(house1)
# Out:
# --- Printing house object (default) ---
# Owned by 'Elon Mask' with 4 members and have (193) vehicles.
# "Owned by 'Elon Mask' with 4 members and have (193) vehicles."

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return self.x + other.x, self.y + other.y

    def __str__(self):
        return f"({self.x}, {self.y})"

p1 = Point(1, 2)
p2 = Point(3, 4)
p3 = p1+p2
print(p3)
# Out:
# (4, 6)

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __sub__(self, other):
        return self.x - other.x, self.y - other.y

    def __str__(self):
        return f"({self.x}, {self.y})"

p1 = Point(1, 2)
p2 = Point(3, 4)
p3 = p1-p2
print(p3)
# Out:
# (-2, -2)

# %% [markdown]
# # ### Common Magic Method: `__len__(self)`
# #
# # *   **Purpose:** Returns the "length" of the object.
# # *   **Called By:** `len(obj)`.
# # *   **Return Value:** Must return a non-negative integer.
# #
# # Useful for objects that represent collections or have a quantifiable size.

# %%
class Playlist:
    def __init__(self, name):
        self.name = name
        self._songs = []

    def add_song(self, title):
        self._songs.append(title)
        print(f"Added '{title}' to playlist '{self.name}'.")

    def __len__(self):
        return len(self._songs)

   
    def __str__(self):
        song_list = "\n  - ".join(self._songs)
        if not song_list:
             return f"Playlist '{self.name}' (0 songs)"
        return f"Playlist '{self.name}' ({len(self)} songs):\n  - {song_list}"


# Create a playlist
my_playlist = Playlist("Chill Vibes")
my_playlist.add_song("Let her go")
my_playlist.add_song("Perfect - Ed Sheeran")
my_playlist.add_song("Until I Found You - Stephen Sanchez")
my_playlist.add_song("The Night We Met - Lord Huron")
my_playlist.add_song("Syndicate - Bipul Chettri")



print(f"Length of playlist: {len(my_playlist)}")
print(my_playlist)
# Out:
# Added 'Let her go' to playlist 'Chill Vibes'.
# Added 'Perfect - Ed Sheeran' to playlist 'Chill Vibes'.
# Added 'Until I Found You - Stephen Sanchez' to playlist 'Chill Vibes'.
# Added 'The Night We Met - Lord Huron' to playlist 'Chill Vibes'.
# Added 'Syndicate - Bipul Chettri' to playlist 'Chill Vibes'.
# Length of playlist: 5
# Playlist 'Chill Vibes' (5 songs):
#   - Let her go
#   - Perfect - Ed Sheeran
#   - Until I Found You - Stephen Sanchez
#   - The Night We Met - Lord Huron
#   - Syndicate - Bipul Chettri

# %%
class Animal:
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        print("Woof!")

class Cat(Animal):
    def speak(self):
        print("Meow!")

animals = [Dog(), Cat()]

for a in animals:
    a.speak()
# Out:
# Woof!
# Meow!

# %% [markdown]
# ## Operator Overloading (Polymorphism with Operators)

# %%
print(5 + 3)        # integer addition
print("Hi " + "There")  # string concatenation
print([1,2] + [3,4])     # list concatenation
#Same operator + works differently depending on type.
# Out:
# 8
# Hi There
# [1, 2, 3, 4]

# %% [markdown]
# ## Built-in Function Polymorphism

# %%
print(len("Hello"))       # string length
print(len([1,2,3,4]))    # list length
print(len({"a":1, "b":2})) # dictionary length
#len() works with multiple types.
# Out:
# 5
# 4
# 2

# %%
class Book:
    def __init__(self, title, pages):
        self.title = title
        self.pages = pages

    # Overload the + operator to add pages of two books
    def __add__(self, other):
        return self.pages + other.pages

# Create two Book objects
book1 = Book("Python Basics", 120)
book2 = Book("Data Science", 150)

# Use + operator
total_pages = book1 + book2
print("Total pages:", total_pages)
# Out:
# Total pages: 270

# %%
class RepeatString:
    def __init__(self, text):
        self.text = text

    def __mul__(self, times):
        return self.text * times

s = RepeatString("Hi ")
print(s * 3)
# Out:
# Hi Hi Hi

# %%
class Printer:
    def operate(self):
        print("Printing Documents")
class Scanner:
    def operate(self):
        print( "Scanning Documents")
def use_device(device):
    device.operate()
printer=Printer()
scanner=Scanner()
devices=[printer,scanner]
for i in devices:
    use_device(i)
# Out:
# Printing Documents
# Scanning Documents

# %%
class Employee:
    def calculate_salary(self):
        pass
class FullTimeEmployee(Employee):
    def calculate_salary(self):
        print("Salary = Monthly fixed salary")
class ParttimeEmployee(Employee):
    def calculate_salary(self):
        print("Salary = Hourly wage")
obj1=FullTimeEmployee()
obj2=ParttimeEmployee()
employee=[obj1,obj2]
for i in employee:
    i.calculate_salary()
# Out:
# Salary = Monthly fixed salary
# Salary = Hourly wage

# %%
class Distance:
    def __init__(self,meters):
        self.meters=meters
    def __add__(self,other):
        return self.meters+other.meters

d1=Distance(5)
d2=Distance(10)
d3=(d1+d2)
print(d3)
# Out:
# 15
